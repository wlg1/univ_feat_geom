# %% [markdown]
# # setup

# %%
# %%capture
# !git clone https://github.com/saprmarks/feature-circuits.git
# %cd feature-circuits
# !pip install -r requirements.txt

# %%
# import sys
# sys.path.append('/content/feature-circuits')

# %%
# !git submodule update --init  # this will download an older vers that doesn't use from_pretrained
# Out:
# Submodule 'dictionary_learning' (https://github.com/saprmarks/dictionary_learning.git) registered for path 'dictionary_learning'
# Cloning into '/content/feature-circuits/dictionary_learning'...
# Submodule path 'dictionary_learning': checked out '614883f9476613e7c1c48b951cd3947451e1f534'

# %%
# !git clone https://github.com/saprmarks/dictionary_learning.git
# Out:
# Cloning into 'dictionary_learning'...
# remote: Enumerating objects: 763, done.
# remote: Counting objects: 100% (215/215), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 763 (delta 200), reused 181 (delta 181), pack-reused 548
# Receiving objects: 100% (763/763), 367.25 KiB | 10.20 MiB/s, done.
# Resolving deltas: 100% (501/501), done.

# %%
# !bash dictionary_learning/pretrained_dictionary_downloader.sh
# Out:
# --2024-05-14 21:29:21--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/attn_out_layer0/10_32768/ae.pt
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134352680 (128M)
# Saving to: ‘dictionaries/pythia-70m-deduped/attn_out_layer0/10_32768/ae.pt’
#
# ae.pt               100%[===================>] 128.13M  1.87MB/s    in 50s
#
# 2024-05-14 21:30:11 (2.56 MB/s) - ‘dictionaries/pythia-70m-deduped/attn_out_layer0/10_32768/ae.pt’ saved [134352680/134352680]
#
# --2024-05-14 21:30:11--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/attn_out_layer0/10_32768/config.json
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322 [application/json]
# Saving to: ‘dictionaries/pythia-70m-deduped/attn_out_layer0/10_32768/config.json’
#
# config.json         100%[===================>]     322  --.-KB/s    in 0s
#
# 2024-05-14 21:30:12 (193 MB/s) - ‘dictionaries/pythia-70m-deduped/attn_out_layer0/10_32768/config.json’ saved [322/322]
#
# --2024-05-14 21:30:12--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/mlp_out_layer0/10_32768/ae.pt
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134352680 (128M)
# Saving to: ‘dictionaries/pythia-70m-deduped/mlp_out_layer0/10_32768/ae.pt’
#
# ae.pt               100%[===================>] 128.13M  1.75MB/s    in 71s
#
# 2024-05-14 21:31:23 (1.80 MB/s) - ‘dictionaries/pythia-70m-deduped/mlp_out_layer0/10_32768/ae.pt’ saved [134352680/134352680]
#
# --2024-05-14 21:31:23--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/mlp_out_layer0/10_32768/config.json
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322 [application/json]
# Saving to: ‘dictionaries/pythia-70m-deduped/mlp_out_layer0/10_32768/config.json’
#
# config.json         100%[===================>]     322  --.-KB/s    in 0s
#
# 2024-05-14 21:31:23 (237 MB/s) - ‘dictionaries/pythia-70m-deduped/mlp_out_layer0/10_32768/config.json’ saved [322/322]
#
# --2024-05-14 21:31:23--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/resid_out_layer0/10_32768/ae.pt
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134352680 (128M)
# Saving to: ‘dictionaries/pythia-70m-deduped/resid_out_layer0/10_32768/ae.pt’
#
# ae.pt               100%[===================>] 128.13M  2.12MB/s    in 72s
#
# 2024-05-14 21:32:36 (1.78 MB/s) - ‘dictionaries/pythia-70m-deduped/resid_out_layer0/10_32768/ae.pt’ saved [134352680/134352680]
#
# --2024-05-14 21:32:36--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/resid_out_layer0/10_32768/config.json
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322 [application/json]
# Saving to: ‘dictionaries/pythia-70m-deduped/resid_out_layer0/10_32768/config.json’
#
# config.json         100%[===================>]     322  --.-KB/s    in 0s
#
# 2024-05-14 21:32:36 (143 MB/s) - ‘dictionaries/pythia-70m-deduped/resid_out_layer0/10_32768/config.json’ saved [322/322]
#
# --2024-05-14 21:32:36--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/attn_out_layer1/10_32768/ae.pt
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134352680 (128M)
# Saving to: ‘dictionaries/pythia-70m-deduped/attn_out_layer1/10_32768/ae.pt’
#
# ae.pt               100%[===================>] 128.13M  1.99MB/s    in 30s
#
# 2024-05-14 21:33:07 (4.26 MB/s) - ‘dictionaries/pythia-70m-deduped/attn_out_layer1/10_32768/ae.pt’ saved [134352680/134352680]
#
# --2024-05-14 21:33:07--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/attn_out_layer1/10_32768/config.json
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322 [application/json]
# Saving to: ‘dictionaries/pythia-70m-deduped/attn_out_layer1/10_32768/config.json’
#
# config.json         100%[===================>]     322  --.-KB/s    in 0s
#
# 2024-05-14 21:33:07 (286 MB/s) - ‘dictionaries/pythia-70m-deduped/attn_out_layer1/10_32768/config.json’ saved [322/322]
#
# --2024-05-14 21:33:07--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/mlp_out_layer1/10_32768/ae.pt
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134352680 (128M)
# Saving to: ‘dictionaries/pythia-70m-deduped/mlp_out_layer1/10_32768/ae.pt’
#
# ae.pt               100%[===================>] 128.13M  2.07MB/s    in 51s
#
# 2024-05-14 21:33:58 (2.52 MB/s) - ‘dictionaries/pythia-70m-deduped/mlp_out_layer1/10_32768/ae.pt’ saved [134352680/134352680]
#
# --2024-05-14 21:33:58--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/mlp_out_layer1/10_32768/config.json
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322 [application/json]
# Saving to: ‘dictionaries/pythia-70m-deduped/mlp_out_layer1/10_32768/config.json’
#
# config.json         100%[===================>]     322  --.-KB/s    in 0s
#
# 2024-05-14 21:33:59 (138 MB/s) - ‘dictionaries/pythia-70m-deduped/mlp_out_layer1/10_32768/config.json’ saved [322/322]
#
# --2024-05-14 21:33:59--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/resid_out_layer1/10_32768/ae.pt
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134352680 (128M)
# Saving to: ‘dictionaries/pythia-70m-deduped/resid_out_layer1/10_32768/ae.pt’
#
# ae.pt               100%[===================>] 128.13M  1.27MB/s    in 70s
#
# 2024-05-14 21:35:09 (1.83 MB/s) - ‘dictionaries/pythia-70m-deduped/resid_out_layer1/10_32768/ae.pt’ saved [134352680/134352680]
#
# --2024-05-14 21:35:09--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/resid_out_layer1/10_32768/config.json
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322 [application/json]
# Saving to: ‘dictionaries/pythia-70m-deduped/resid_out_layer1/10_32768/config.json’
#
# config.json         100%[===================>]     322  --.-KB/s    in 0s
#
# 2024-05-14 21:35:09 (157 MB/s) - ‘dictionaries/pythia-70m-deduped/resid_out_layer1/10_32768/config.json’ saved [322/322]
#
# --2024-05-14 21:35:09--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/attn_out_layer2/10_32768/ae.pt
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134352680 (128M)
# Saving to: ‘dictionaries/pythia-70m-deduped/attn_out_layer2/10_32768/ae.pt’
#
# ae.pt               100%[===================>] 128.13M  1.20MB/s    in 84s
#
# 2024-05-14 21:36:33 (1.53 MB/s) - ‘dictionaries/pythia-70m-deduped/attn_out_layer2/10_32768/ae.pt’ saved [134352680/134352680]
#
# --2024-05-14 21:36:33--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/attn_out_layer2/10_32768/config.json
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322 [application/json]
# Saving to: ‘dictionaries/pythia-70m-deduped/attn_out_layer2/10_32768/config.json’
#
# config.json         100%[===================>]     322  --.-KB/s    in 0s
#
# 2024-05-14 21:36:34 (175 MB/s) - ‘dictionaries/pythia-70m-deduped/attn_out_layer2/10_32768/config.json’ saved [322/322]
#
# --2024-05-14 21:36:34--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/mlp_out_layer2/10_32768/ae.pt
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134352680 (128M)
# Saving to: ‘dictionaries/pythia-70m-deduped/mlp_out_layer2/10_32768/ae.pt’
#
# ae.pt               100%[===================>] 128.13M  1.37MB/s    in 85s
#
# 2024-05-14 21:37:59 (1.50 MB/s) - ‘dictionaries/pythia-70m-deduped/mlp_out_layer2/10_32768/ae.pt’ saved [134352680/134352680]
#
# --2024-05-14 21:37:59--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/mlp_out_layer2/10_32768/config.json
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322 [application/json]
# Saving to: ‘dictionaries/pythia-70m-deduped/mlp_out_layer2/10_32768/config.json’
#
# config.json         100%[===================>]     322  --.-KB/s    in 0s
#
# 2024-05-14 21:38:00 (187 MB/s) - ‘dictionaries/pythia-70m-deduped/mlp_out_layer2/10_32768/config.json’ saved [322/322]
#
# --2024-05-14 21:38:00--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/resid_out_layer2/10_32768/ae.pt
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134352680 (128M)
# Saving to: ‘dictionaries/pythia-70m-deduped/resid_out_layer2/10_32768/ae.pt’
#
# ae.pt               100%[===================>] 128.13M  1007KB/s    in 78s
#
# 2024-05-14 21:39:19 (1.63 MB/s) - ‘dictionaries/pythia-70m-deduped/resid_out_layer2/10_32768/ae.pt’ saved [134352680/134352680]
#
# --2024-05-14 21:39:19--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/resid_out_layer2/10_32768/config.json
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322 [application/json]
# Saving to: ‘dictionaries/pythia-70m-deduped/resid_out_layer2/10_32768/config.json’
#
# config.json         100%[===================>]     322  --.-KB/s    in 0s
#
# 2024-05-14 21:39:19 (151 MB/s) - ‘dictionaries/pythia-70m-deduped/resid_out_layer2/10_32768/config.json’ saved [322/322]
#
# --2024-05-14 21:39:19--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/attn_out_layer3/10_32768/ae.pt
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134352680 (128M)
# Saving to: ‘dictionaries/pythia-70m-deduped/attn_out_layer3/10_32768/ae.pt’
#
# ae.pt               100%[===================>] 128.13M  1.82MB/s    in 52s
#
# 2024-05-14 21:40:11 (2.46 MB/s) - ‘dictionaries/pythia-70m-deduped/attn_out_layer3/10_32768/ae.pt’ saved [134352680/134352680]
#
# --2024-05-14 21:40:11--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/attn_out_layer3/10_32768/config.json
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322 [application/json]
# Saving to: ‘dictionaries/pythia-70m-deduped/attn_out_layer3/10_32768/config.json’
#
# config.json         100%[===================>]     322  --.-KB/s    in 0s
#
# 2024-05-14 21:40:12 (201 MB/s) - ‘dictionaries/pythia-70m-deduped/attn_out_layer3/10_32768/config.json’ saved [322/322]
#
# --2024-05-14 21:40:12--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/mlp_out_layer3/10_32768/ae.pt
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134352680 (128M)
# Saving to: ‘dictionaries/pythia-70m-deduped/mlp_out_layer3/10_32768/ae.pt’
#
# ae.pt               100%[===================>] 128.13M  5.28MB/s    in 20s
#
# 2024-05-14 21:40:32 (6.34 MB/s) - ‘dictionaries/pythia-70m-deduped/mlp_out_layer3/10_32768/ae.pt’ saved [134352680/134352680]
#
# --2024-05-14 21:40:32--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/mlp_out_layer3/10_32768/config.json
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322 [application/json]
# Saving to: ‘dictionaries/pythia-70m-deduped/mlp_out_layer3/10_32768/config.json’
#
# config.json         100%[===================>]     322  --.-KB/s    in 0s
#
# 2024-05-14 21:40:32 (163 MB/s) - ‘dictionaries/pythia-70m-deduped/mlp_out_layer3/10_32768/config.json’ saved [322/322]
#
# --2024-05-14 21:40:32--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/resid_out_layer3/10_32768/ae.pt
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134352680 (128M)
# Saving to: ‘dictionaries/pythia-70m-deduped/resid_out_layer3/10_32768/ae.pt’
#
# ae.pt               100%[===================>] 128.13M  1.61MB/s    in 69s
#
# 2024-05-14 21:41:42 (1.85 MB/s) - ‘dictionaries/pythia-70m-deduped/resid_out_layer3/10_32768/ae.pt’ saved [134352680/134352680]
#
# --2024-05-14 21:41:42--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/resid_out_layer3/10_32768/config.json
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322 [application/json]
# Saving to: ‘dictionaries/pythia-70m-deduped/resid_out_layer3/10_32768/config.json’
#
# config.json         100%[===================>]     322  --.-KB/s    in 0s
#
# 2024-05-14 21:41:42 (131 MB/s) - ‘dictionaries/pythia-70m-deduped/resid_out_layer3/10_32768/config.json’ saved [322/322]
#
# --2024-05-14 21:41:42--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/attn_out_layer4/10_32768/ae.pt
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134352680 (128M)
# Saving to: ‘dictionaries/pythia-70m-deduped/attn_out_layer4/10_32768/ae.pt’
#
# ae.pt               100%[===================>] 128.13M  2.04MB/s    in 77s
#
# 2024-05-14 21:43:00 (1.66 MB/s) - ‘dictionaries/pythia-70m-deduped/attn_out_layer4/10_32768/ae.pt’ saved [134352680/134352680]
#
# --2024-05-14 21:43:00--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/attn_out_layer4/10_32768/config.json
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322 [application/json]
# Saving to: ‘dictionaries/pythia-70m-deduped/attn_out_layer4/10_32768/config.json’
#
# config.json         100%[===================>]     322  --.-KB/s    in 0s
#
# 2024-05-14 21:43:00 (173 MB/s) - ‘dictionaries/pythia-70m-deduped/attn_out_layer4/10_32768/config.json’ saved [322/322]
#
# --2024-05-14 21:43:00--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/mlp_out_layer4/10_32768/ae.pt
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134352680 (128M)
# Saving to: ‘dictionaries/pythia-70m-deduped/mlp_out_layer4/10_32768/ae.pt’
#
# ae.pt               100%[===================>] 128.13M  1.68MB/s    in 46s
#
# 2024-05-14 21:43:47 (2.77 MB/s) - ‘dictionaries/pythia-70m-deduped/mlp_out_layer4/10_32768/ae.pt’ saved [134352680/134352680]
#
# --2024-05-14 21:43:47--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/mlp_out_layer4/10_32768/config.json
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322 [application/json]
# Saving to: ‘dictionaries/pythia-70m-deduped/mlp_out_layer4/10_32768/config.json’
#
# config.json         100%[===================>]     322  --.-KB/s    in 0s
#
# 2024-05-14 21:43:47 (152 MB/s) - ‘dictionaries/pythia-70m-deduped/mlp_out_layer4/10_32768/config.json’ saved [322/322]
#
# --2024-05-14 21:43:47--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/resid_out_layer4/10_32768/ae.pt
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134352680 (128M)
# Saving to: ‘dictionaries/pythia-70m-deduped/resid_out_layer4/10_32768/ae.pt’
#
# ae.pt               100%[===================>] 128.13M  3.85MB/s    in 42s
#
# 2024-05-14 21:44:30 (3.03 MB/s) - ‘dictionaries/pythia-70m-deduped/resid_out_layer4/10_32768/ae.pt’ saved [134352680/134352680]
#
# --2024-05-14 21:44:30--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/resid_out_layer4/10_32768/config.json
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322 [application/json]
# Saving to: ‘dictionaries/pythia-70m-deduped/resid_out_layer4/10_32768/config.json’
#
# config.json         100%[===================>]     322  --.-KB/s    in 0s
#
# 2024-05-14 21:44:30 (95.2 MB/s) - ‘dictionaries/pythia-70m-deduped/resid_out_layer4/10_32768/config.json’ saved [322/322]
#
# --2024-05-14 21:44:30--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/attn_out_layer5/10_32768/ae.pt
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134352680 (128M)
# Saving to: ‘dictionaries/pythia-70m-deduped/attn_out_layer5/10_32768/ae.pt’
#
# ae.pt               100%[===================>] 128.13M  4.78MB/s    in 20s
#
# 2024-05-14 21:44:51 (6.29 MB/s) - ‘dictionaries/pythia-70m-deduped/attn_out_layer5/10_32768/ae.pt’ saved [134352680/134352680]
#
# --2024-05-14 21:44:51--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/attn_out_layer5/10_32768/config.json
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322 [application/json]
# Saving to: ‘dictionaries/pythia-70m-deduped/attn_out_layer5/10_32768/config.json’
#
# config.json         100%[===================>]     322  --.-KB/s    in 0s
#
# 2024-05-14 21:44:51 (242 MB/s) - ‘dictionaries/pythia-70m-deduped/attn_out_layer5/10_32768/config.json’ saved [322/322]
#
# --2024-05-14 21:44:51--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/mlp_out_layer5/10_32768/ae.pt
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134352680 (128M)
# Saving to: ‘dictionaries/pythia-70m-deduped/mlp_out_layer5/10_32768/ae.pt’
#
# ae.pt               100%[===================>] 128.13M  1.68MB/s    in 82s
#
# 2024-05-14 21:46:13 (1.57 MB/s) - ‘dictionaries/pythia-70m-deduped/mlp_out_layer5/10_32768/ae.pt’ saved [134352680/134352680]
#
# --2024-05-14 21:46:13--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/mlp_out_layer5/10_32768/config.json
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322 [application/json]
# Saving to: ‘dictionaries/pythia-70m-deduped/mlp_out_layer5/10_32768/config.json’
#
# config.json         100%[===================>]     322  --.-KB/s    in 0s
#
# 2024-05-14 21:46:13 (169 MB/s) - ‘dictionaries/pythia-70m-deduped/mlp_out_layer5/10_32768/config.json’ saved [322/322]
#
# --2024-05-14 21:46:13--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/resid_out_layer5/10_32768/ae.pt
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134352680 (128M)
# Saving to: ‘dictionaries/pythia-70m-deduped/resid_out_layer5/10_32768/ae.pt’
#
# ae.pt               100%[===================>] 128.13M  5.63MB/s    in 8.6s
#
# 2024-05-14 21:46:22 (14.8 MB/s) - ‘dictionaries/pythia-70m-deduped/resid_out_layer5/10_32768/ae.pt’ saved [134352680/134352680]
#
# --2024-05-14 21:46:22--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/resid_out_layer5/10_32768/config.json
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322 [application/json]
# Saving to: ‘dictionaries/pythia-70m-deduped/resid_out_layer5/10_32768/config.json’
#
# config.json         100%[===================>]     322  --.-KB/s    in 0s
#
# 2024-05-14 21:46:22 (162 MB/s) - ‘dictionaries/pythia-70m-deduped/resid_out_layer5/10_32768/config.json’ saved [322/322]
#
# --2024-05-14 21:46:22--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/embed/10_32768/ae.pt
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134352680 (128M)
# Saving to: ‘dictionaries/pythia-70m-deduped/embed/10_32768/ae.pt’
#
# ae.pt               100%[===================>] 128.13M  1.19MB/s    in 57s
#
# 2024-05-14 21:47:20 (2.24 MB/s) - ‘dictionaries/pythia-70m-deduped/embed/10_32768/ae.pt’ saved [134352680/134352680]
#
# --2024-05-14 21:47:20--  https://baulab.us/u/smarks/autoencoders/pythia-70m-deduped/embed/10_32768/config.json
# Resolving baulab.us (baulab.us)... 129.10.121.189
# Connecting to baulab.us (baulab.us)|129.10.121.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322 [application/json]
# Saving to: ‘dictionaries/pythia-70m-deduped/embed/10_32768/config.json’
#
# config.json         100%[===================>]     322  --.-KB/s    in 0s
#
# 2024-05-14 21:47:20 (173 MB/s) - ‘dictionaries/pythia-70m-deduped/embed/10_32768/config.json’ saved [322/322]
#
# Download completed.

# %%
import os
# Create the directory if it doesn't exist
os.makedirs('circuits', exist_ok=True)

# %%
# !bash scripts/get_circuit.sh rc_train 0.1 0.01 none 6 10
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Batches:   0% 0/10 [00:00<?, ?it/s]You're using a GPTNeoXTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# 2024-05-15 14:08:21.075921: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-15 14:08:21.075986: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-15 14:08:21.078141: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-15 14:08:22.619706: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Batches: 100% 10/10 [11:29<00:00, 68.91s/it]

# %%
# !bash scripts/evaluate_circuit.sh circuits/rc_train_dict10_node0.1_edge0.01_n100_aggnone.pt rc_test 0.1 6 10
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# # features = 32
# # triangles = 13
# You're using a GPTNeoXTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# 2024-05-15 14:52:18.742681: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-15 14:52:18.742739: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-15 14:52:18.744626: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-15 14:52:19.966245: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# F(M) = 1.6403992176055908
# F(C) = 0.332000732421875
# F(C') = 0.03996887430548668
# F(∅) = -0.01942138746380806
# faithfulness = 0.2117229700088501
# completeness = 0.0357811339199543
