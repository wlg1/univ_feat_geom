# %%
1
# Out:
# 1

# %%
import json

with open('metrics_dict.json') as f:
    scores = json.load(f)

# %%
scores
# Out:
# {'mean_activ_corr': {'gemma_2_2b-layer_3/width_16k/canonical_vs_gemma_2_9b-layer_0/width_16k/canonical': '0.16060254122481865',
#   'gemma_2_2b-layer_3/width_16k/canonical_vs_gemma_2_9b-layer_1/width_16k/canonical': '0.1176405541629606',
#   'gemma_2_2b-layer_3/width_16k/canonical_vs_gemma_2_9b-layer_2/width_16k/canonical': '0.09630269902527289',
#   'gemma_2_2b-layer_3/width_16k/canonical_vs_gemma_2_9b-layer_3/width_16k/canonical': '0.12236877897646536',
#   'gemma_2_2b-layer_3/width_16k/canonical_vs_gemma_2_9b-layer_4/width_16k/canonical': '0.094326545569686',
#   'gemma_2_2b-layer_3/width_16k/canonical_vs_gemma_2_9b-layer_5/width_16k/canonical': '0.09169036766769523',
#   'gemma_2_2b-layer_3/width_16k/canonical_vs_gemma_2_9b-layer_6/width_16k/canonical': '0.08871901557381534',
#   'gemma_2_2b-layer_3/width_16k/canonical_vs_gemma_2_9b-layer_7/width_16k/canonical': '0.08853216105597994',
# ...
